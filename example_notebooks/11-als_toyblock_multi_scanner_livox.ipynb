# %% [markdown]
# # Light Multi-Channel ALS Demo with Toyblocks Scene
# Notebook: Hannah Weiser & Sina Zumstein, 2023
#
# This demo scene showcases various toyblock models scanned by airborne laserscanning. We will use the command-line access of HELIOS++ to run the simulation, and use Python just for displaying the input XMLs and the resulting point clouds.

# %%
import sys, os
from pathlib import Path
from IPython.display import Code

current_folder = globals()["_dh"][0]
helios_path = str(Path(current_folder).parent)
sys.path.append(helios_path)  # add helios-plusplus directory to PATH
import pyhelios

from pyhelios.util.xmldisplayer import display_xml, find_playback_dir

# %% [markdown]
# ## Survey
# Let us look at the XML files in the simulation. First, we investigate the survey XML file, `light_als_toyblocks_multiscanner.xml`:

# %%
os.chdir(helios_path)
Code(display_xml(r'data\surveys\demo\light_als_toyblocks_multiscanner.xml'), language='XML')
# Out:
# <document>
# 	<platformSettings id="platform1" movePerSec_m="30" z="100.0" />
#     <scannerSettings active="true" id="scanner1" pulseFreq_hz="10000" scanAngle_deg="20.0" scanFreq_hz="100" trajectoryTimeInterval_s="0.01" />
#     <survey name="light_toyblocks_als" platform="data/platforms.xml#sr22" scanner="data/scanners_als.xml#livox-mid-100" scene="data/scenes/toyblocks/light_toyblocks_scene.xml#light_toyblocks_scene">
# 		<leg>
# 			<platformSettings x="-30.0" y="-50.0" template="platform1" />
# 			<scannerSettings template="scanner1" />
# 		</leg>
# 		<leg>
# 			<platformSettings x="70.0" y="-50.0" template="platform1" />
# 			<scannerSettings template="scanner1" active="false" />
# 		</leg>
# 		<leg>
# 			<platformSettings x="70.0" y="0.0" template="platform1" />
# 			<scannerSettings template="scanner1" />
# 		</leg>
# 		<leg>
# 			<platformSettings x="-30.0" y="0.0" template="platform1" />
# 			<scannerSettings template="scanner1" active="false" />
# 		</leg>
# 	</survey>
# </document>

# %% [markdown]
# We can see that there are four `leg` elements which define the waypoints of the platform (`sr22` airplane) trajectory and the speed between these waypoints (`movePerSec_m`). Since the scanner does not record any data between the second and the third leg (`active="false"`), there are only two flight strips.

# %% [markdown]
# ## Scanner
#
# Next we will have a look at the scanner that is placed on the platform. This is the `livox-mid-100` defined in `data/scanners_als.xml` as shown in the survey XML.

# %%
Code(display_xml(r'data/scanners_als.xml', 'livox-mid-100'), language='XML')
# Out:
# <scanner id="livox-mid-100" accuracy_m="0.02" beamDivergence_rad="0.0027" name="livox-mid-100" optics="risley" pulseFreqs_Hz="50000" pulseLength_ns="4" rangeMin_m="2" scanAngleMax_deg="35" scanAngleEffectiveMax_deg="35" rotorFreq1_Hz="7294" rotorFreq2_Hz="-4664" wavelength_nm="905">
# 		<channels>
# 			<channel id="0">
# 				<FWFSettings beamSampleQuality="3" />
# 				<beamOrigin x="0" y="0" z="0">
# 					<rot axis="z" angle_deg="-30" /> <!-- cone center looking left 30 deg -->
# 				</beamOrigin>
# 				<!-- scan plane is defined by the central ray -->
# 			</channel>
# 			<channel id="1">
# 				<FWFSettings beamSampleQuality="3" />
# 				<beamOrigin x="0" y="0" z="0">
# 					<!-- central cone -->
# 				</beamOrigin>
# 			</channel>
# 			<channel id="2">
# 				<FWFSettings beamSampleQuality="3" />
# 				<beamOrigin x="0" y="0" z="0">
# 					<rot axis="z" angle_deg="30" /> <!-- cone center looking right 30 deg -->
# 				</beamOrigin>
# 			</channel>
# 		</channels>
# 		<FWFSettings beamSampleQuality="3" />
# 	</scanner>

# %% [markdown]
# Besides the typical properties, such as `beamDivergence_rad` or `accuracy`, we see a special feature: The scanner has three channels with a different `beamOrigin` each. This way, the multi-channel laser scanner Livox Mid-100 is simulated, which has three LiDAR sensors with overlapping fields of view.
#
# <center><img src=".\images\Livox_img.png" alt="Livox" title="Livox technical figure" width="500">
#
# <i>Multi-channel laser scanner Livox Mid-100. Source: [Livox datasheet](https://www.livoxtech.com/3296f540ecf5458a8829e01cf429798e/downloads/20190530/Livox%20Mid-100%20Quick%20Start%20Guide%20multi%20v1.4.pdf).</i></center>

# %% [markdown]
# ## Scene
#
# Now we will have a look at the scene, `light_toyblocks_scene`in `data/scenes/toyblocks/light_toyblocks_scene.xml`:

# %%
Code(display_xml(r'data/scenes/toyblocks/light_toyblocks_scene.xml','light_toyblocks_scene'))
# Out:
# <scene id="light_toyblocks_scene" name="LightToyblocksScene">
#         <part>
#             <filter type="objloader">
#                 <param type="string" key="filepath" value="data/sceneparts/basic/groundplane/groundplane.obj" />
#             </filter>
#             <filter type="scale">
#                 <param type="double" key="scale" value="70" />
#             </filter>
# 			<filter type="translate">
# 				<param type="vec3" key="offset" value="20.0;0;0" />
# 			</filter>
#         </part>
#         <part>
#             <filter type="objloader">
#                 <param type="string" key="filepath" value="data/sceneparts/toyblocks/cube.obj" />
#             </filter>
# 			<filter type="scale">
#                 <param type="double" key="scale" value="1" />
#             </filter>
#         </part>
# 		<part>
#             <filter type="objloader">
#                 <param type="string" key="filepath" value="data/sceneparts/toyblocks/cube.obj" />
#             </filter>
# 			<filter type="rotate">
# 				<param key="rotation" type="rotation">
# 					<rot angle_deg="45" axis="z" />
# 				</param>
# 			</filter>
# 			<filter type="scale">
#                 <param type="double" key="scale" value="0.5" />
#             </filter>
# 			<filter type="translate">
# 				<param type="integer" key="onGround" value="-1" />
# 				<param type="vec3" key="offset" value="-45.0;10.0;10" />
# 			</filter>
#         </part>
#     </scene>

# %% [markdown]
# This is a simple scene, consisting of a groundplane and two cubes. The cubes are loaded from the same file (`data/sceneparts/cube.obj`) with the `objloader` but the second one is additionally rotated, scaled and translated.

# %% [markdown]
# ## Executing the Simulation
#
# Next, we will run the simulation. In Jupyter Notebooks, we can run external commands with the `!command` syntax, but you can also just run it from the command line. In this demo we will run the simulation twice: One time with the default behaviour, which will create one output per strip with the points from all three scanners and one time with the `--splitByChannel` argument, which will create individual outputs for each scanner.

# %%
!"run/helios.exe" data/surveys/demo/light_als_toyblocks_multiscanner.xml
output_path_joined = find_playback_dir(r"data\surveys\demo\light_als_toyblocks_multiscanner.xml")
# Out:
# HELIOS++ VERSION 1.1.1
#
# CWD: "H:\helios4pyhelios\helios"
# seed: AUTO
# surveyPath: "data/surveys/demo/light_als_toyblocks_multiscanner.xml"
# assetsPath: "assets/"
# outputPath: "output/"
# writeWaveform: 0
# calcEchowidth: 0
# fullWaveNoise: 0
# splitByChannel: 0
# parallelization: 1
# njobs: 0
# chunkSize: 32
# warehouseFactor: 4
# platformNoiseDisabled: 0
# legNoiseDisabled: 0
# rebuildScene: 0
# lasOutput: 0
# las10: 0
# fixedIncidenceAngle: 0
# gpsStartTime:
# kdtType: 4
# kdtJobs: 0
# kdtGeomJobs: 0
# sahLossNodes: 32
#
# xmlDocFilename: light_als_toyblocks_multiscanner.xml
# xmlDocFilePath: data/surveys/demo
# xmlDocFilename: scanners_als.xml
# xmlDocFilePath: data
# Using default value for attribute 'averagePower_w' : 4
# Using default value for attribute 'beamQualityFactor' : 1
# Using default value for attribute 'opticalEfficiency' : 0.99
# Using default value for attribute 'receiverDiameter_m' : 0.15
# Using default value for attribute 'atmosphericVisibility_km' : 23
# Using default value for attribute 'binSize_ns' : 0.25
# Using default value for attribute 'winSize_ns' : 1
# Using default value for attribute 'maxFullwaveRange_ns' : 0
# Using default value for attribute 'headRotatePerSecMax_deg' : 0
# Using default value for attribute 'rangeMax_m' : 1.79769e+308
# Using default value for attribute 'scanFreqMax_Hz' : 0
# Using default value for attribute 'scanFreqMin_Hz' : 0
# Using default value for attribute 'binSize_ns' : 0.25
# Using default value for attribute 'winSize_ns' : 1
# Using default value for attribute 'maxFullwaveRange_ns' : 0
# Number of subsampling rays (0): 19
# Using default value for attribute 'scanFreqMin_Hz' : 0
# Using default value for attribute 'scanFreqMax_Hz' : 0
# Using default value for attribute 'accuracy_m' : 0.02
# Using default value for attribute 'rangeMin_m' : 2
# Using default value for attribute 'rangeMax_m' : 1.79769e+308
# Using default value for attribute 'headRotatePerSecMax_deg' : 0
# Using default value for attribute 'beamDivergence_rad' : 0.0027
# Using default value for attribute 'pulseLength_ns' : 4
# Using default value for attribute 'maxNOR' : 0
# Using default value for attribute 'binSize_ns' : 0.25
# Using default value for attribute 'winSize_ns' : 1
# Using default value for attribute 'maxFullwaveRange_ns' : 0
# Number of subsampling rays (1): 19
# Using default value for attribute 'scanFreqMin_Hz' : 0
# Using default value for attribute 'scanFreqMax_Hz' : 0
# Using default value for attribute 'accuracy_m' : 0.02
# Using default value for attribute 'rangeMin_m' : 2
# Using default value for attribute 'rangeMax_m' : 1.79769e+308
# Using default value for attribute 'headRotatePerSecMax_deg' : 0
# Using default value for attribute 'beamDivergence_rad' : 0.0027
# Using default value for attribute 'pulseLength_ns' : 4
# Using default value for attribute 'maxNOR' : 0
# Using default value for attribute 'binSize_ns' : 0.25
# Using default value for attribute 'winSize_ns' : 1
# Using default value for attribute 'maxFullwaveRange_ns' : 0
# Number of subsampling rays (2): 19
# Using default value for attribute 'scanFreqMin_Hz' : 0
# Using default value for attribute 'scanFreqMax_Hz' : 0
# Using default value for attribute 'accuracy_m' : 0.02
# Using default value for attribute 'rangeMin_m' : 2
# Using default value for attribute 'rangeMax_m' : 1.79769e+308
# Using default value for attribute 'headRotatePerSecMax_deg' : 0
# Using default value for attribute 'beamDivergence_rad' : 0.0027
# Using default value for attribute 'pulseLength_ns' : 4
# Using default value for attribute 'maxNOR' : 0
# xmlDocFilename: platforms.xml
# xmlDocFilePath: data
# Using default value for attribute 'y' : 0
# Using default value for attribute 'x' : 0
# Number of subsampling rays (0): 19
# Using default value for attribute 'numRuns' : 1
# Using default value for attribute 'simSpeed' : 1
# Using default value for attribute 'stripId' : NULL_STRIP_ID
# Using platform default value for attribute 'x' : 0
# Using platform default value for attribute 'y' : 0
# Using platform default value for attribute 'onGround' : 0
# Using platform default value for attribute 'stopAndTurn' : 1
# Using platform default value for attribute 'smoothTurn' : 0
# Using platform default value for attribute 'slowdownEnabled' : 1
# Using default value for attribute 'name' : Unnamed platformSettings asset
# Using platform default value for attribute 'z' : 100
# Using platform default value for attribute 'onGround' : 0
# Using platform default value for attribute 'stopAndTurn' : 1
# Using platform default value for attribute 'smoothTurn' : 0
# Using platform default value for attribute 'slowdownEnabled' : 1
# Using platform default value for attribute 'movePerSec_m' : 30
# Using scanner default value for attribute 'beamDivergence_rad' : 0.003
# Using default value for attribute 'name' : Unnamed scannerSettings asset
# Using scanner default value for attribute 'active' : 1
# Using scanner default value for attribute 'pulseFreq_hz' : 10000
# Using scanner default value for attribute 'scanFreq_hz' : 100
# Using scanner default value for attribute 'beamDivergence_rad' : 0.003
# Using scanner default value for attribute 'trajectoryTimeInterval_s' : 0.01
# Using default value for attribute 'stripId' : NULL_STRIP_ID
# Using platform default value for attribute 'z' : 100
# Using platform default value for attribute 'onGround' : 0
# Using platform default value for attribute 'stopAndTurn' : 1
# Using platform default value for attribute 'smoothTurn' : 0
# Using platform default value for attribute 'slowdownEnabled' : 1
# Using platform default value for attribute 'movePerSec_m' : 30
# Using scanner default value for attribute 'pulseFreq_hz' : 10000
# Using scanner default value for attribute 'scanFreq_hz' : 100
# Using scanner default value for attribute 'beamDivergence_rad' : 0.003
# Using scanner default value for attribute 'trajectoryTimeInterval_s' : 0.01
# Using default value for attribute 'stripId' : NULL_STRIP_ID
# Using platform default value for attribute 'z' : 100
# Using platform default value for attribute 'onGround' : 0
# Using platform default value for attribute 'stopAndTurn' : 1
# Using platform default value for attribute 'smoothTurn' : 0
# Using platform default value for attribute 'slowdownEnabled' : 1
# Using platform default value for attribute 'movePerSec_m' : 30
# Using scanner default value for attribute 'active' : 1
# Using scanner default value for attribute 'pulseFreq_hz' : 10000
# Using scanner default value for attribute 'scanFreq_hz' : 100
# Using scanner default value for attribute 'beamDivergence_rad' : 0.003
# Using scanner default value for attribute 'trajectoryTimeInterval_s' : 0.01
# Using default value for attribute 'stripId' : NULL_STRIP_ID
# Using platform default value for attribute 'z' : 100
# Using platform default value for attribute 'onGround' : 0
# Using platform default value for attribute 'stopAndTurn' : 1
# Using platform default value for attribute 'smoothTurn' : 0
# Using platform default value for attribute 'slowdownEnabled' : 1
# Using platform default value for attribute 'movePerSec_m' : 30
# Using scanner default value for attribute 'pulseFreq_hz' : 10000
# Using scanner default value for attribute 'scanFreq_hz' : 100
# Using scanner default value for attribute 'beamDivergence_rad' : 0.003
# Using scanner default value for attribute 'trajectoryTimeInterval_s' : 0.01
# Loading Scene...
# Reading serial scene wrapper object from data/scenes/toyblocks/light_toyblocks_scene.scene ...
# Building KD-Grove...
# KDTree (num. primitives 26) :
# 	Max. # primitives in leaf: 12
# 	Min. # primitives in leaf: 2
# 	Max. depth reached: 14
# 	KDTree axis-aligned surface area: 50448.3
# 	Interior nodes: 88
# 	Leaf nodes: 70
# 	Total tree cost: 5.39028
# KDGrove stats:
# 	Number of trees: 1
# 	Number of static trees: 1
# 	Number of dynamic trees: 0
# 	Statistics (min, max, total, mean, stdev):
# 		Building time: (0.0160, 0.0160, 0.0160, 0.0160, 0.0000)
# 		Tree primitives: (26, 26, 26, 26.0000, 0.0000)
# 		Max primitives in leaf: (12, 12, 12, 12.0000, 0.0000)
# 		Min primitives in leaf: (2, 2, 2, 2.0000, 0.0000)
# 		Maximum depth: (14, 14, 14, 14.0000, 0.0000)
# 		Axis-aligned surface area: (50448.2765, 50448.2765, 50448.2765, 50448.2765, 0.0000)
# 		Number of interior nodes: (88, 88, 88, 88.0000, 0.0000)
# 		Number of leaf nodes: (70, 70, 70, 70.0000, 0.0000)
# 		Tree cost: (5.3903, 5.3903, 5.3903, 5.3903, 0.0000)
#
# KDG built in 0.016s
# Scene loaded in 0.022s
# Reading Spectral Library...
# Using default value for attribute 'seed' : AUTO
# Output directory: "output/\light_toyblocks_als\2023-02-09_15-11-11\"
# Simulation: Scanner changed!
# Starting leg 0
#
# Pulse frequency set to 10000
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Iterative mode was used for manual leg initialization because default one failed for MovingPlatform
# Leg0 waypoints:
# 	Origin: (20, 20, 100.231)
# 	Target: (120, 20, 100.231)
# 	Next: (120, 70, 100.231)
#
# Running simulation...
# Clearing point cloud: "output/\light_toyblocks_als\2023-02-09_15-11-11\leg000_points.xyz"
# Survey 0.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 1.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 0.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 2.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 1.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 3.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 1.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 4.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 2.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 5.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 2.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 6.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 2.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 7.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 3.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 8.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 3.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 9.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 4.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 10.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 4.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 11.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 4.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 12.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 5.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 13.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 5.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 14.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 6.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 15.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 6.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 16.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 6.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 17.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 7.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 18.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 7.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 19.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 8.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 20.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 8.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 21.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 8.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 22.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 9.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 23.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 9.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 24.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 10.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 25.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 10.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 26.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 10.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 27.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 11.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 28.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 11.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 29.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 12.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 30.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 12.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 31.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 12.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 32.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 13.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 33.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 13.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 34.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 14.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 35.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 14.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 36.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 14.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 37.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 15.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 38.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 15.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 39.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 16.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 40.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 16.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 41.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 16.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 42.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 17.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 43.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 17.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 44.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 18.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 45.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 18.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 46.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 18.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 47.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 19.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 48.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 19.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 49.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 20.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 50.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 20.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 51.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 20.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 52.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 21.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 53.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 21.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 54.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 22.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 55.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 22.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 56.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 22.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 57.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 23.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 58.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 23.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 59.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 24.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 60.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 24.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 61.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 24.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 62.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 25.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 63.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 25.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 64.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 26.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 65.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 26.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 66.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 26.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 67.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 27.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 68.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 27.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 69.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 28.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 70.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 28.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 71.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 28.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 72.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 29.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 73.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 29.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 74.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 30.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 75.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 30.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 76.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 30.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 77.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 31.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 78.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 31.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 79.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 32.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 80.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 32.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 81.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 32.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 82.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 33.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 83.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 33.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 84.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 34.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 85.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 34.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 86.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 34.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 87.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 35.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 88.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 35.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 89.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 36.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 90.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 36.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 91.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 36.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 92.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 37.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 93.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 37.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 94.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 38.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 95.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 38.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 96.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 38.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 97.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 39.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 98.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 39.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg1/3 99.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Waypoint reached!
# Starting leg 1
#
# Pulse frequency set to 10000
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Leg1 waypoints:
# 	Origin: (120, 20, 100.231)
# 	Target: (120, 70, 100.231)
# 	Next: (20, 70, 100.231)
#
# Survey 40.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 1.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 40.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 2.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 40.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 3.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 40.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 4.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 41.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 5.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 41.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 6.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 41.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 7.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 41.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 8.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 41.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 9.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 42.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 10.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 42.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 11.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 42.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 12.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 42.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 13.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 42.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 14.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 43.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 15.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 43.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 16.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 43.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 17.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 43.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 18.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 43.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 19.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 44.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 20.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 44.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 21.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 44.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 22.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 44.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 23.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 44.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 24.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 45.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 25.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 45.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 26.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 45.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 27.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 45.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 28.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 45.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 29.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 46.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 30.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 46.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 31.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 46.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 32.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 46.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 33.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 46.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 34.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 47.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 35.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 47.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 36.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 47.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 37.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 47.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 38.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 47.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 39.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 48.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 40.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 48.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 41.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 48.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 42.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 48.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 43.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 48.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 44.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 49.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 45.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 49.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 46.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 49.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 47.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 49.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 48.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 49.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 49.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 50.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 50.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 50.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 51.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 50.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 52.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 50.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 53.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 50.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 54.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 51.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 55.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 51.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 56.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 51.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 57.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 51.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 58.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 51.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 59.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 52.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 60.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 52.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 61.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 52.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 62.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 52.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 63.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 52.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 64.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 53.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 65.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 53.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 66.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 53.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 67.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 53.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 68.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 53.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 69.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 54.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 70.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 54.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 71.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 54.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 72.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 54.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 73.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 54.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 74.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 55.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 75.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 55.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 76.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 55.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 77.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 55.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 78.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 55.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 79.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 56.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 80.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 56.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 81.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 56.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 82.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 56.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 83.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 56.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 84.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 57.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 85.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 57.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 86.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 57.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 87.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 57.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 88.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 57.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 89.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 58.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 90.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 58.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 91.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 58.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 92.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 58.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 93.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 58.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 94.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 59.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 95.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 59.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 96.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 59.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 97.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 59.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 98.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 59.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg2/3 99.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Waypoint reached!
# Starting leg 2
#
# Pulse frequency set to 10000
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Leg2 waypoints:
# 	Origin: (120, 70, 100.231)
# 	Target: (20, 70, 100.231)
# 	Next: (20, 70, 100.231)
#
# Clearing point cloud: "output/\light_toyblocks_als\2023-02-09_15-11-11\leg002_points.xyz"
# Survey 60.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 1.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 60.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 2.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 61.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 3.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 61.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 4.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 62.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 5.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 62.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 6.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 62.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 7.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 63.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 8.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 63.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 9.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 64.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 10.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 64.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 11.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 64.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 12.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 65.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 13.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 65.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 14.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 66.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 15.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 66.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 16.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 66.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 17.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 67.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 18.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 67.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 19.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 68.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 20.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 68.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 21.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 68.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 22.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 69.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 23.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 69.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 24.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 70.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 25.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 70.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 26.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 70.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 27.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 71.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 28.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 71.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 29.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 72.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 30.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 72.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 31.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 72.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 32.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 73.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 33.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 73.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 34.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 74.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 35.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 74.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 36.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 74.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 37.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 75.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 38.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 75.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 39.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 76.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 40.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 76.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 41.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 76.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 42.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 77.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 43.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 77.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 44.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 78.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 45.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 78.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 46.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 78.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 47.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 79.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 48.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 79.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 49.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 80.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 50.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 80.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 51.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 80.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 52.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 81.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 53.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 81.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 54.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 82.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 55.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 82.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 56.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 82.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 57.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 83.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 58.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 83.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 59.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 84.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 60.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 84.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 61.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 84.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 62.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 85.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 63.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 85.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 64.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 86.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 65.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 86.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 66.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 86.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 67.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 87.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 68.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 87.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 69.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 88.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 70.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 88.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 71.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 88.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 72.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 89.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 73.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 89.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 74.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 90.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 75.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 90.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 76.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 90.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 77.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 91.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 78.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 91.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 79.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 92.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 80.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 92.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 81.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 92.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 82.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 93.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 83.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 93.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 84.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 94.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 85.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 94.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 86.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 94.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 87.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 95.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 88.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 95.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 89.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 96.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 90.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 96.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 91.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 96.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 92.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 97.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 93.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 97.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 94.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 98.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 95.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 98.40%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 96.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 98.80%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 97.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 99.20%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 98.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Survey 99.60%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Leg3/3 99.00%	Elapsed 00 00:00:00 Remaining 00 00:00:00
# Waypoint reached!
# Starting leg 3
#
# Pulse frequency set to 10000
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Scan angle set to 20 degrees.
# Scan frequency set to 100 Hz.
# Waypoint reached!
# Elapsed simulation steps = 83339
# Elapsed virtual time = 8.3339 sec.
# Main thread simulation loop finished in 1.04956 sec.
# Waiting for completion of pulse computation tasks...
# Pulse computation tasks finished in 1.04986 sec.
# Total simulation time: 0:00:1

# %%
# -q flag will result in only errors printed to the log
!"run/helios.exe" data/surveys/demo/light_als_toyblocks_multiscanner.xml --splitByChannel -q
output_path_split_by_channel = find_playback_dir(r"data\surveys\demo\light_als_toyblocks_multiscanner.xml")

# %% [markdown]
# ## The results
# Now we can display the 3D plots.
#
# ### 1) Full point cloud
# We start with the point cloud of the first simuation and we color it by **object ID**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from pathlib import Path

print("Loading points from", Path(output_path_joined).relative_to(helios_path).as_posix())


strip_1 = np.loadtxt(Path(output_path_joined) / 'leg000_points.xyz')
strip_2 = np.loadtxt(Path(output_path_joined) / 'leg002_points.xyz')

#stacking the strips 
strips= np.vstack((strip_1, strip_2))

traj_1 = np.loadtxt(Path(output_path_joined) / 'leg000_trajectory.txt')
traj_2 = np.loadtxt(Path(output_path_joined) / 'leg002_trajectory.txt')

traj = np.vstack((traj_1[:, :3], traj_2[:, :3]))
# Out:
# Loading points from output/light_toyblocks_als/2023-02-09_15-11-11

# %%
def set_axes_equal(ax):
    '''Make axes of 3D plot have equal scale so that spheres appear as spheres,
    cubes as cubes, etc..  This is one possible solution to Matplotlib's
    ax.set_aspect('equal') and ax.axis('equal') not working for 3D.

    Input
      ax: a matplotlib axis, e.g., as output from plt.gca().
    '''

    x_limits = ax.get_xlim3d()
    y_limits = ax.get_ylim3d()
    z_limits = ax.get_zlim3d()

    x_range = abs(x_limits[1] - x_limits[0])
    x_middle = np.mean(x_limits)
    y_range = abs(y_limits[1] - y_limits[0])
    y_middle = np.mean(y_limits)
    z_range = abs(z_limits[1] - z_limits[0])
    z_middle = np.mean(z_limits)

    # The plot bounding box is a sphere in the sense of the infinity
    # norm, hence I call half the max range the plot radius.
    plot_radius = 0.5*max([x_range, y_range, z_range])

    ax.set_xlim3d([x_middle - plot_radius, x_middle + plot_radius]) 
    ax.set_ylim3d([y_middle - plot_radius, y_middle + plot_radius])
    ax.set_zlim3d([z_middle - plot_radius, z_middle + plot_radius])

# %%
# Matplotlib figures.
fig = plt.figure(figsize=(15,10))


#settings for a discrete colorbar
N=3
cmap=plt.get_cmap('jet',N)

# Scatter plot of first scanner (coloured by hitObjectId).
ax = fig.add_subplot(1,3,1, projection='3d')
sc = ax.scatter(strips[:, 0], strips[:, 1], strips[:, 2], c=strips[:, 8], cmap=cmap, s=0.02)

# Plot of trajectory.
ax.plot(traj[:,0], traj[:,1], traj[:,2], c = 'black')

# Add axis labels.
ax.set_xlabel('$X$')
ax.set_ylabel('$Y$')
ax.set_zlabel('$Z$')

set_axes_equal(ax)    

# Set title.
ax.set_title(label='Point cloud and trajectory', fontsize=18)

cax = plt.axes([0.4, 0.35, 0.01, 0.25])
cbar = plt.colorbar(sc, cax=cax, ticks=[1-2/3, 1, 1+2/3])

cbar.set_label("Object Id", fontsize=15)
cbar.ax.set_yticklabels(['0', '1', '2'])

# Display results
plt.show()

# %% [markdown]
# ### 2) Separate point clouds by channel
#
# Now we can create 3D plots for each scanner seperately.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

print("Loading points from", Path(output_path_split_by_channel).relative_to(helios_path).as_posix())

# we load the output of each scanner and strip seperately

strip_1_dev0 = np.loadtxt(Path(output_path_split_by_channel) / 'leg000_points_dev0.xyz')
strip_1_dev1 = np.loadtxt(Path(output_path_split_by_channel) / 'leg000_points_dev1.xyz')
strip_1_dev2 = np.loadtxt(Path(output_path_split_by_channel) / 'leg000_points_dev2.xyz')

strip_2_dev0= np.loadtxt(Path(output_path_split_by_channel) / 'leg002_points_dev0.xyz')
strip_2_dev1= np.loadtxt(Path(output_path_split_by_channel) / 'leg002_points_dev1.xyz')
strip_2_dev2= np.loadtxt(Path(output_path_split_by_channel) / 'leg002_points_dev2.xyz')

#stacking the strips for each scanner

strips_dev0 = np.vstack((strip_1_dev0, strip_2_dev0))
strips_dev1 = np.vstack((strip_1_dev1, strip_2_dev1))
strips_dev2 = np.vstack((strip_1_dev2, strip_2_dev2))

# load and stack the trajectory points

traj_1 = np.loadtxt(Path(output_path_split_by_channel) / 'leg000_trajectory.txt')
traj_2 = np.loadtxt(Path(output_path_split_by_channel) / 'leg002_trajectory.txt')

traj = np.vstack((traj_1[:, :3], traj_2[:, :3]))
# Out:
# Loading points from output/light_toyblocks_als/2023-02-09_15-11-12

# %%
# Matplotlib figures.
fig = plt.figure(figsize=(20,15))

for i, strips in enumerate([strips_dev0, strips_dev1, strips_dev2]):

    # Scatter plot of points from respective scanner (coloured by GpsTime).
    ax = fig.add_subplot(1,3,i+1, projection='3d')
    sc = ax.scatter(strips[:, 0], strips[:, 1], strips[:, 2], c=strips[:, 10], cmap='viridis', s=0.02)

    # Plot of trajectory.
    ax.plot(traj[:,0], traj[:,1], traj[:,2], c = 'black')

    # Add axis labels.
    ax.set_xlabel('$X$')
    ax.set_ylabel('$Y$')
    ax.set_zlabel('$Z$')

    set_axes_equal(ax)    

    # Set title.
    ax.set_title(label=f'Point cloud of scanner {i+1}', fontsize=18)

cbar = plt.colorbar(sc, orientation='horizontal' , ax=ax)
cbar.set_label("GpsTime", fontsize=15)

# Display results
plt.show()
